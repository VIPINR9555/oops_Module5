# %%
                                              ## OOPS ASSIGNMENT MODULE 5 ##

# %%
Q1  - What is Object-Oriented Programming (OOPs)?
Ans - Object-Oriented Programming (OOP) is a programming paradigm that revolves around the concept of objects and classes.
      It's a way of designing and organizing code that simulates real-world objects and systems.

# %%
Q2  - What is a class in OOPs?
Ans - In Object-Oriented Programming (OOP), a class is a blueprint or template that defines the properties and behavior of
      an object. It's a fundamental concept in OOP that enables the creation of objects that share common characteristics
      and actions.

# %%
Q3  - What is an object in OOPs?
Ans - An Object-Oriented Programming (OOP), an object is an instance of a class, which represents a real-world entity or concept.
      An object has its own set of attributes (data) and methods (functions) that describe and define its behavior.

# %%
Q4  - What is the difference between abstraction and encapsulation?
Ans - #Abstraction:

      Abstraction is the process of exposing only the necessary information to the outside world while hiding the implementation details.
      It's about defining an interface or a contract that specifies what an object can do, without revealing how it does it.

      Abstraction helps to:
      1. Reduce complexity
      2. Improve modularity
      3. Increase flexibility
      4. Enhance maintainability


      #Encapsulation:

      Encapsulation is the process of bundling data and methods that operate on that data within a single unit, called a class or 
      object. It's about hiding the internal implementation details of an object from the outside world and only exposing the necessary
      information through public methods.

      Encapsulation helps to:

      1. Hide internal implementation details
      2. Protect data from external interference
      3. Improve data integrity
      4. Enhance security

# %%
Q5 -  What are dunder methods in Python?
Ans - In Python, "dunder" is a colloquial term that refers to special methods that begin and end with double underscores (__).
      These methods are also known as "magic methods" or "special methods."

# %%
Q6 - Explain the concept of inheritance in OOP.
Ans - Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows one class to inherit the properties
      and behavior of another class. The class that is being inherited from is called the parent or superclass, while the class
      that is doing the inheriting is called the child or subclass.

# %%
Q7 -  What is polymorphism in OOP?
Ans - Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows objects of different classes to
      be treated as objects of a common superclass. It enables objects to take on multiple forms, depending on the context in 
      which they are used.

# %%
Q8 -  How is encapsulation achieved in Python?
Ans - Encapsulation is achieved in Python by using classes and objects to bundle data and methods that operate on that data.

# %%
Q9 - What is a constructor in Python?
Ans - In Python, a constructor is a special method that is automatically called when an object of a class is instantiated
      (created). The constructor is used to initialize the attributes of the class and set up the object's internal state.

# %%
Q10 - What are class and static methods in Python?
Ans - #Class Methods

      A class method is a method that is bound to the class rather than the instance of the class. It can access or modify the
      class state, i.e., the class variables. Class methods are used when we want to define a method that is related to the class 
      itself, rather than an instance of the class.

     - Class methods are defined using the @classmethod decorator.
     - The first argument to a class method is always the class itself, which is referenced as cls by convention.
     - Class methods can access and modify class variables.

     #Static Methods

     A static method is a method that belongs to a class, rather than an instance of the class. Static methods are used when we want
     to define a method that is related to the class, but does not need to access or modify the class state.

     - Static methods are defined using the @staticmethod decorator.
     - Static methods do not take any implicit arguments (like self or cls).
     - Static methods cannot access or modify class variables.

# %%
Q11 - What is method overloading in Python?
Ans - Method overloading is a feature in some programming languages that allows multiple methods with the same name to be defined,
      as long as they have different parameter lists.

# %%
Q12 - What is method overriding in OOP?
Ans - Method overriding is a fundamental concept in Object-Oriented Programming (OOP) that allows a subclass to provide a different
      implementation of a method that is already defined in its superclass.

# %%
Q13 - What is a property decorator in Python?
Ans - In Python, a property decorator is a special type of decorator that allows you to customize access to instance variables.
      It provides a way to implement getters, setters, and deleters for instance variables, making it easier to control how they 
      are accessed and modified.

# %%
Q14 - Why is polymorphism important in OOP?
Ans - Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows objects of different classes to be
      treated as objects of a common superclass. This is important for several reasons:

      Reasons for Importance of Polymorphism

      #1. Increased Flexibility

         Polymorphism allows for more flexibility in programming, as objects of different classes can be treated as objects of a 
         common superclass. This makes it easier to write code that can work with a variety of different objects.

      #2. Easier Code Maintenance

         Polymorphism makes it easier to maintain code, as changes to a superclass can automatically be applied to all subclasses.
         This reduces the amount of code that needs to be modified, making maintenance easier.

      #3. Improved Code Reusability

         Polymorphism enables code reusability, as methods defined in a superclass can be inherited by subclasses. This reduces the
         amount of code that needs to be written, making development more efficient.

      #4. Enhanced Extensibility

         Polymorphism makes it easier to extend existing code, as new subclasses can be added without modifying the existing code.
         This makes it easier to add new features or functionality to an existing system.

      #5. Simplified Code

         Polymorphism can simplify code, as objects of different classes can be treated as objects of a common superclass. This
         reduces the amount of code that needs to be written, making it easier to understand and maintain.

      #6. Real-World Modeling

         Polymorphism allows for more accurate modeling of real-world objects and systems, as objects of different classes can be
         treated as objects of a common superclass. This makes it easier to model complex systems and relationships.

     #7. Improved Error Handling

         Polymorphism can improve error handling, as methods defined in a superclass can handle errors in a way that is common to
         all subclasses. This reduces the amount of code that needs to be written to handle errors.

# %%
Q15 - What is an abstract class in Python?
Ans - In Python, an abstract class is a class that cannot be instantiated and is intended to be inherited by other classes. 
      Abstract classes are used to define a blueprint for other classes to follow, and they often contain abstract methods, which 
      are methods that are declared but not implemented.

# %%
Q16 - What are the advantages of OOP?
Ans - #1. Modularity

         OOP allows for modular programming, where a program is broken down into smaller, independent modules (objects) that can be
         easily maintained, updated, and reused.

      #2. Code Reusability

         OOP enables code reusability through inheritance, where a new class can inherit the properties and behavior of an existing
         class. This reduces code duplication and saves development time.

      #3. Encapsulation

         OOP provides encapsulation, which hides the internal details of an object from the outside world and only exposes the necessary
         information through public methods. This improves code security and reduces coupling.

      #4. Abstraction

         OOP allows for abstraction, which enables developers to focus on essential features of an object while ignoring non-essential
         details. This simplifies complex systems and improves code readability.

      #5. Improved Reliability

         OOP promotes improved reliability through the use of encapsulation, abstraction, and inheritance. These features help reduce
         errors, improve code quality, and ensure that code changes have minimal impact on other parts of the system.

      #6. Easier Maintenance

         OOP makes it easier to maintain and modify code through the use of modular, reusable, and well-encapsulated objects. This
         reduces the time and effort required to make changes and improves overall system flexibility.

      #7. Faster Development

         OOP enables faster development through the use of pre-built classes, objects, and libraries. This reduces the amount of code
         that needs to be written from scratch and accelerates the development process.

# %%
Q17 - What is the difference between a class variable and an instance variable?
Ans   #Class Variable:

      A class variable is a variable that is shared by all instances of a class. It is defined inside the class definition, but outside any
      instance method. Class variables are also known as static variables.
        
     #Instance Variable:
    
     An instance variable is a variable that is unique to each instance of a class. It is defined inside an instance method, typically
     in the `__init__` method.

# %%
Q18 - What is multiple inheritance in Python?
Ans - Multiple inheritance in Python is a feature that allows a class to inherit properties and methods from more than one superclass
      or parent class. This means that a class can have multiple base classes, and it inherits all the attributes and methods from all 
      of them.

# %%
Q19 - F Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
Ans - The purpose of the__str__ method is to provide a concise and informative string that summarizes the object's state. This method
      is often used to display information about an object in a user-friendly way.
    
      The purpose of the __repr__ method is to provide a string that can be used to recreate the object. This method is often used
      for debugging and logging purposes, as it provides a more detailed and formal representation of the object.

# %%
Q20 - What is the significance of the ‘super()’ function in Python?
Ans - The super() function in Python is a built-in function that allows you to access methods and properties of a parent class
      (also known as a superclass) from a child class (also known as a subclass). The super() function is used to invoke the methods
      of the parent class.

# %%
Q21 - What is the significance of the __del__ method in Python?
Ans - n Python, the __del__ method is a special method that is automatically called when an object is about to be destroyed.
      This method is also known as the destructor or finalizer.

# %%
Q22 - What is the difference between @staticmethod and @classmethod in Python?
Ans - @staticmethod

      A static method is a method that belongs to a class, rather than an instance of the class. It does not have access to the class
      or instance variables.

      - No implicit first argument (no self or cls).
      - Can be called without creating an instance of the class.
      - Cannot access or modify class or instance variables.

      @classmethod

      A class method is a method that is bound to the class, rather than an instance of the class. It has access to the class variables,
      but not instance variables.

     - Implicit first argument is the class itself (cls).
     - Can be called without creating an instance of the class.
     - Can access or modify class variables.

# %%
Q23 -How does polymorphism work in Python with inheritance?
Ans - Polymorphism in Python with inheritance allows you to create objects of different classes that can be treated as objects of a
      common superclass. This enables you to write code that can work with a variety of different classes, without knowing the specific
      class of the object at compile time.

      How Polymorphism Works:

      1. Inheritance: Create a superclass (also known as a parent or base class) and one or more subclasses (also known as child or
                      derived classes) that inherit from the superclass.
      2. Method Overriding: In the subclasses, override the methods of the superclass to provide specific implementations for each subclass.
      3. Polymorphic Behavior: Create objects of the subclasses and treat them as objects of the superclass. When you call a method on an
                               object, Python will automatically call the overridden method in the subclass, if it exists.

# %%
Q24 - What is method chaining in Python OOP?
Ans - Method chaining is a technique in Python Object-Oriented Programming (OOP) where multiple methods are called on an object in a
      single line of code. Each method returns the object itself, allowing the next method to be called on the same object.

# %%
Q25 - What is the purpose of the __call__ method in Python?
Ans - In Python, the __call__ method is a special method that allows an instance of a class to be called as a function. This means
      that an object can be invoked like a function, with parentheses () containing any necessary arguments.

# %%
                                                    ## PRACTICAL QUESTIONS ##

# %%
Q1 -  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".
Ans - # Define the parent class Animal
      class Animal:
      def speak(self):
      print("The animal makes a sound.")

      # Define the child class Dog that inherits from Animal
      class Dog(Animal):
      # Override the speak() method
      def speak(self):
      print("Bark!")

     # Create an instance of Dog
     my_dog = Dog()

     # Call the speak() method
     my_dog.speak()  # Output: Bark!

     # Create an instance of Animal
       animal = Animal()

    # Call the speak() method
      animal.speak()  
    # Output: The animal makes a sound.

# %%
Q2 - Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
     from it and implement the area() method in both.
Ans - from abc import ABC, abstractmethod
      import math

      # Define the abstract class Shape
      class Shape(ABC):
      @abstractmethod
      def area(self):
      pass

     # Define the Circle class that inherits from Shape
     class Circle(Shape):
     def __init__(self, radius):
     self.radius = radius

     # Implement the area() method
     def area(self):
     return math.pi * (self.radius ** 2)

     # Define the Rectangle class that inherits from Shape
     class Rectangle(Shape):
     def __init__(self, length, width):
     self.length = length
     self.width = width

    # Implement the area() method
    def area(self):
    return self.length * self.width

    # Create instances of Circle and Rectangle
    circle = Circle(5)
    rectangle = Rectangle(4, 6)

    # Calculate and print the areas
    print(f"Circle area: {circle.area():.2f}")
    print(f"Rectangle area: {rectangle.area()}")

# %%
Q3 - Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
     and further derive a class ElectricCar that adds a battery attribute.
Ans - # Define the base class Vehicle
      class Vehicle:
      def __init__(self, type):
      self.type = type

      def display_details(self):
      print(f"Vehicle Type: {self.type}")

      # Derive the class Car from Vehicle
      class Car(Vehicle):
      def __init__(self, type, brand, model):
      super().__init__(type)  # Call the Vehicle class constructor
      self.brand = brand
      self.model = model

      def display_details(self):
      super().display_details()  # Call the Vehicle class display_details method
      print(f"Brand: {self.brand}, Model: {self.model}")

      # Derive the class ElectricCar from Car
      class ElectricCar(Car):
      def __init__(self, type, brand, model, battery_capacity):
      super().__init__(type, brand, model)  # Call the Car class constructor
      self.battery_capacity = battery_capacity

      def display_details(self):
      super().display_details()  # Call the Car class display_details method
      print(f"Battery Capacity: {self.battery_capacity} kWh")

      # Create an instance of ElectricCar
      my_electric_car = ElectricCar("Car", "Tesla", "Model S", 75)

      # Display the details of the ElectricCar
      my_electric_car.display_details()


     #Output:
     Vehicle Type: Car
     Brand: Tesla, Model: Model S
     Battery Capacity: 75 kWh

# %%
Q4 - same as Q3

# %%
Q5  - Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
      balance and methods to deposit, withdraw, and check balance.
Ans - Here is a Python code snippet that demonstrates encapsulation using a BankAccount class:


      class BankAccount:
      def __init__(self, initial_balance=0):
      self.__balance = initial_balance  # Private attribute

      def deposit(self, amount):
      if amount > 0:
      self.__balance += amount
      print(f"Deposited ${amount}. Current balance: ${self.__balance}")
      else:
      print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. Current balance: ${self.__balance}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def check_balance(self):
        print(f"Current balance: ${self.__balance}")

    # Create a BankAccount instance
      account = BankAccount(1000)

    # Demonstrate encapsulation
      account.deposit(500)
      account.withdraw(200)
      account.check_balance()

    # Attempt to access private attribute directly (will raise an AttributeError)
    try:
    print(account.__balance)
    except AttributeError:
    print("Error: Cannot access private attribute directly.")


    #Output:
     Deposited $500. Current balance: $1500
     Withdrew $200. Current balance: $1300
     Current balance: $1300
     Error: Cannot access private attribute directly.

# %%
Q6  - Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
      and Piano that implement their own version of play().
Ans -  #Define the base class Instrument
       class Instrument:
       def play(self):
        print("Playing a musical instrument.")

     # Derive the Guitar class from Instrument
     class Guitar(Instrument):
     def play(self):
        print("Strumming the guitar.")

     # Derive the Piano class from Instrument
      class Piano(Instrument):
      def play(self):
        print("Pressing the piano keys.")

     # Create a list of Instrument objects
     instruments = [Guitar(), Piano(), Instrument()]

     # Demonstrate runtime polymorphism
      for instrument in instruments:
       instrument.play()


     #Output:
           Strumming the guitar.
           Pressing the piano keys.
           Playing a musical instrument.

# %%
Q7 -  Create a class MathOperations with a class method add_numbers() to add two numbers and a static
      method subtract_numbers() to subtract two numbers.
Ans - class MathOperations:
    # Class method to add two numbers
    @classmethod
    def add_numbers(cls, num1, num2):
        return num1 + num2

    # Static method to subtract two numbers
    @staticmethod
    def subtract_numbers(num1, num2):
        return num1 - num2

    # Example usage:
    print("Adding numbers using class method:")
    result = MathOperations.add_numbers(10, 5)
    print(f"Result: {result}")

    print("\nSubtracting numbers using static method:")
    result = MathOperations.subtract_numbers(10, 5)
    print(f"Result: {result}")


    #Output:


     Adding numbers using class method:
     Result: 15

     Subtracting numbers using static method:
     Result: 5

# %%
Q8 - Implement a class Person with a class method to count the total number of persons created.
Ans - class Person:
    # Class attribute to store the count of persons
    person_count = 0

    # Constructor to initialize person attributes
    def __init__(self, name, age):
        self.name = name
        self.age = age
        # Increment the person count in the constructor
        Person.person_count += 1

    # Class method to get the total person count
    @classmethod
    def get_person_count(cls):
        return cls.person_count

# %%
Q9 -  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
      fraction as "numerator/denominator".
Ans - class Fraction:
       def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    # Override the __str__ method to display the fraction as "numerator/denominator"
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"
     # Example usage:
     fraction1 = Fraction(3, 4)
     print(fraction1)  # Output: 3/4

     fraction2 = Fraction(1, 2)
     print(fraction2)  # Output: 1/2

     # Attempt to create a fraction with a zero denominator
    try:
    fraction3 = Fraction(5, 0)
    except ValueError as e:
    print(e) 
    # Output: 
     Denominator cannot be zero.

# %%
Q10 -  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
       vectors.
Ans -  class Vector:
        def __init__(self, x, y):
        self.x = x
        self.y = y

    # Override the __add__ method to add two vectors
    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Unsupported operand type for +")

    # Override the __str__ method to display the vector as (x, y)
    def __str__(self):
        return f"({self.x}, {self.y})"

     # Example usage:
     vector1 = Vector(2, 3)
     vector2 = Vector(4, 5)

     # Add two vectors using the + operator
     result_vector = vector1 + vector2
     print(f"Vector 1: {vector1}")
     print(f"Vector 2: {vector2}")
     print(f"Result Vector: {result_vector}")

    # Attempt to add a vector with a non-vector object
    try:
    result_vector = vector1 + "non-vector object"
    except TypeError as e:
    print(e)  # Output: Unsupported operand type for +


    #Output:
     Vector 1: (2, 3)
     Vector 2: (4, 5)
     Result Vector: (6, 8)
     Unsupported operand type for +

# %%
Q11 -  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
       {name} and I am {age} years old."
Ans - class Person:
       def __init__(self, name, age):
        self.name = name
        self.age = age

       def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

     # Example usage:
     person1 = Person("John Doe", 30)
     person2 = Person("Jane Doe", 25)

    person1.greet()  # Output: Hello, my name is John Doe and I am 30 years old.
    person2.greet()  # Output: Hello, my name is Jane Doe and I am 25 years old.

# %%
Q12 -  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
       the average of the grades.
Ans - class Student:
       def __init__(self, name, grades=None):
        self.name = name
        self.grades = grades if grades is not None else []

      def add_grade(self, grade):
        self.grades.append(grade)

      def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)


       # Example usage:
       student1 = Student("John Doe")
       student1.add_grade(85)
       student1.add_grade(90)
       student1.add_grade(78)

       print(f"Student Name: {student1.name}")
       print(f"Grades: {student1.grades}")
       print(f"Average Grade: {student1.average_grade():.2f}")

       student2 = Student("Jane Doe", [92, 88, 95])
       print(f"\nStudent Name: {student2.name}")
       print(f"Grades: {student2.grades}")
       print(f"Average Grade: {student2.average_grade():.2f}")


      #Output:
      Student Name: John Doe
      Grades: [85, 90, 78]
      Average Grade: 84.33

      Student Name: Jane Doe
      Grades: [92, 88, 95]
      Average Grade: 91.67

# %%
Q13 -  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
Ans -  class Rectangle:
        def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set the dimensions of the rectangle
    def set_dimensions(self, length, width):
        if length <= 0 or width <= 0:
            raise ValueError("Dimensions must be positive numbers.")
        self.length = length
        self.width = width

    # Method to calculate the area of the rectangle
    def area(self):
        return self.length * self.width


     # Example usage:
    rectangle = Rectangle()
    rectangle.set_dimensions(5, 4)
    print(f"Rectangle dimensions: Length = {rectangle.length}, Width = {rectangle.width}")
    print(f"Rectangle area: {rectangle.area()}")

     # Attempt to set invalid dimensions
    try:
    rectangle.set_dimensions(-3, 4)
    except ValueError as e:
    print(e)  # Output: Dimensions must be positive numbers.


    #Output:

    Rectangle dimensions: Length = 5, Width = 4
    Rectangle area: 20
    Dimensions must be positive numbers.

# %%
Q14 - Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
      and hourly rate. Create a derived class Manager that adds a bonus to the salary.
Ans - class Employee:
      def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    # Method to calculate the salary
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

    class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    # Override the calculate_salary method to include the bonus
    def calculate_salary(self):
        return super().calculate_salary() + self.bonus


      # Example usage:
     employee = Employee("John Doe", 40, 50)
     print(f"Employee Name: {employee.name}")
     print(f"Employee Salary: ${employee.calculate_salary():.2f}")

     manager = Manager("Jane Doe", 40, 60, 1000)
     print(f"\nManager Name: {manager.name}")
     print(f"Manager Salary: ${manager.calculate_salary():.2f}")


    #Output:
    Employee Name: John Doe
    Employee Salary: $2000.00

     Manager Name: Jane Doe
     Manager Salary: $2600.00

# %%
Q15 -  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
       calculates the total price of the product.
Ans -  class Product:
       def __init__(self, name, price, quantity):
       self.name = name
       self.price = price
       self.quantity = quantity

    # Method to calculate the total price of the product
    def total_price(self):
        return self.price * self.quantity

    # Method to display product details
    def display_details(self):
        print(f"Product Name: {self.name}")
        print(f"Price: ${self.price:.2f}")
        print(f"Quantity: {self.quantity}")
        print(f"Total Price: ${self.total_price():.2f}")
        
        # Example usage:
      product1 = Product("Laptop", 999.99, 2)
      product1.display_details()

      product2 = Product("Smartphone", 599.99, 3)
      product2.display_details()


      #Output:
      Product Name: Laptop
      Price: $999.99
      Quantity: 2
      Total Price: $1999.98

      Product Name: Smartphone
      Price: $599.99
      Quantity: 3
      Total Price: $1799.97

# %%
Q16 -  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
       implement the sound() method.
Ans -   from abc import ABC, abstractmethod

      # Define the abstract base class Animal
     class Animal(ABC):
     @abstractmethod
     def sound(self):
        pass

    # Derived class Cow that implements the sound() method
   class Cow(Animal):
    def sound(self):
        return "Moo!"

    # Derived class Sheep that implements the sound() method
    class Sheep(Animal):
    def sound(self):
        return "Baa!"

    # Example usage:
   def make_sound(animal: Animal):
    print(animal.sound())

    cow = Cow()
   sheep = Sheep()

    make_sound(cow) 
   # Output: Moo!
    make_sound(sheep)
    # Output: Baa!
   #Output:
    Moo!
    Baa!

# %%
Q17 - Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
       returns a formatted string with the book's details.
Ans -  class Book:
      def __init__(self, title, author, year_published):
        """
        Initialize a Book object.

        Args:
            title (str): The title of the book.
            author (str): The author of the book.
            year_published (int): The year the book was published.
        """
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        """
        Return a formatted string with the book's details.

        Returns:
            str: A formatted string containing the book's title, author, and year published.
        """
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

     # Example usage:
     book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
     book2 = Book("1984", "George Orwell", 1949)

     print(book1.get_book_info())
     print(book2.get_book_info())


    #Output:
   'To Kill a Mockingbird' by Harper Lee, published in 1960
   '1984' by George Orwell, published in 1949

# %%
Q18 - Create a class House with attributes address and price. Create a derived class Mansion that adds an
      attribute number_of_rooms.
Ans - class House:
      def __init__(self, address, price):
        """
        Initialize a House object.

        Args:
            address (str): The address of the house.
            price (float): The price of the house.
        """
        self.address = address
        self.price = price

      def display_details(self):
        """
        Display the details of the house.
        """
        print(f"Address: {self.address}")
        print(f"Price: ${self.price:.2f}")

     class Mansion(House):
     def __init__(self, address, price, number_of_rooms):
        """
        Initialize a Mansion object.

        Args:
            address (str): The address of the mansion.
            price (float): The price of the mansion.
            number_of_rooms (int): The number of rooms in the mansion.
        """
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def display_details(self):
        """
        Display the details of the mansion.
        """
        super().display_details()
        print(f"Number of Rooms: {self.number_of_rooms}")

     # Example usage:
     house = House("123 Main St", 500000)
     house.display_details()

    mansion = Mansion("456 Luxury Dr", 2000000, 10)
    mansion.display_details()


    #Output:
    Address: 123 Main St
    Price: $500000.00

    Address: 456 Luxury Dr
    Price: $2000000.00
    Number of Rooms: 10
